# %%
import pandas as pd

# %%
comments = pd.read_parquet(
    "dailyMailSentimentComment.parquet.snappy", engine="fastparquet"
)

# %%
articles = pd.read_parquet("dailymailWithSentiment.parquet.snappy", engine="fastparquet")

# %%
comments.head()
# Out:
#                                                 link  \
# 0  https://www.dailymail.co.uk/news/article-12155...
# 1  https://www.dailymail.co.uk/news/article-12155...
# 2  https://www.dailymail.co.uk/news/article-12155...
# 3  https://www.dailymail.co.uk/news/article-12155...
# 4  https://www.dailymail.co.uk/news/article-12155...
#
#                                              comment  Sentiment  Polarity
# 0  Russians don't appear to understand that peopl...  -0.183453  Negative
# 1  The Russians dont like it up em do they? They ...  -0.183453  Negative
# 2                         well, russians wanted war.  -0.183453  Negative
# 3             wait till the war gets to Moscow  ....  -0.183453  Negative
# 4  Russians hate Britain\nAnd what they particula...  -0.183453  Negative

# %%
articles.head()
# Out:
#        Unnamed: 0                                              title  \
# index
# 0               0  Wave of looting ravages Russian border area am...
# 1               1  EXCLUSIVE: 'This is the beginning of the end o...
# 2               2  Naked protest at St Peter's Basilica: Man stri...
# 3               3  Russia accuses Apple of 'close cooperation' wi...
# 4               4  Foster mother who 'rescued' orphans from Ukrai...
#
#                                           author      date  \
# index
# 0                 Will Stewart, Christian Oliver  03/06/23
# 1                                Chris Pleasance  03/06/23
# 2                               Christian Oliver  02/06/23
# 3      Keith Griffith For Dailymail.com, Reuters  01/06/23
# 4                                       Ed Wight  01/06/23
#
#                                                     text  \
# index
# 0      A wave of looting has reportedly hit a border ...
# ...

# %%
ds = (
    comments.merge(
        articles, how="right", on="link", suffixes=("_Comments", "_Articles")
    )
    .drop(axis=1, labels="comment")
    .drop_duplicates(subset="link")
)

# %%
ds.head()
# Out:
#                                                  link  Sentiment_Comments  \
# 0   https://www.dailymail.co.uk/news/article-12155...           -0.183453
# 10  https://www.dailymail.co.uk/news/article-12152...           -0.069692
# 20  https://www.dailymail.co.uk/news/article-12151...           -0.024046
# 30  https://www.dailymail.co.uk/news/article-12150...           -0.115326
# 40  https://www.dailymail.co.uk/news/article-12148...           -0.174184
#
#    Polarity_Comments  Unnamed: 0  \
# 0           Negative           0
# 10          Negative           1
# 20           Neutral           2
# 30          Negative           3
# 40          Negative           4
#
#                                                 title  \
# 0   Wave of looting ravages Russian border area am...
# 10  EXCLUSIVE: 'This is the beginning of the end o...
# 20  Naked protest at St Peter's Basilica: Man stri...
# 30  Russia accuses Apple of 'close cooperation' wi...
# ...

# %%
ds.to_parquet("dailySentimentComplete.parquet.snappy", engine="fastparquet")
