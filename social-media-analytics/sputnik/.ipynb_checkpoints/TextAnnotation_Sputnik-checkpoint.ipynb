# %% [markdown]
# ##### Social Media Analytics
# ### Introduction to Text Mining
# ## Text Annotation
# (c) Nuno Antonio 2019-2022 v1.02

# %% [markdown]
# ### Initial setup

# %%
# Import packages
import csv
import pandas as pd
import numpy as np
import nltk 
import re
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
import spacy
# Out:
#   File "/var/folders/v4/8yk6c62s7nv77xj532727jcr0000gn/T/ipykernel_16877/4195836472.py", line 10
#     import python -m spacy download en_core_web_sm
#                   ^
# SyntaxError: invalid syntax

# %%
ds = pd.read_parquet("sputnikSentimentComplete.parquet.snappy", engine="fastparquet")

# %%
ds["date"] = pd.to_datetime(ds["date"], format="%d/%m/%y")

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/henrique/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/henrique/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# ### Functions

# %%
# Text preprocessing
def textPreProcess(rawText, removeHTML=True, charsToRemove = r"\?|\.|\!|\;|\.|\"|\,|\(|\)|\&|\:|\-| u |\'s|\/\/t|\[|\]|\*", removeNumbers=True, removeLineBreaks=False, specialCharsToRemove = r'[^\x00-\xfd]', convertToLower=True, removeConsecutiveSpaces=True):
    if type(rawText) != str:
        return rawText
    procText = rawText
        
    # Remove HTML
    if removeHTML:
        procText = BeautifulSoup(procText,'html.parser').get_text()

    # Remove punctuation and other special characters
    if len(charsToRemove)>0:
        procText = re.sub(charsToRemove,' ',procText)

    # Remove numbers
    if removeNumbers:
        procText = re.sub(r'\d+',' ',procText)

    # Remove line breaks
    if removeLineBreaks:
        procText = procText.replace('\n',' ').replace('\r', '')

    # Remove special characters
    if len(specialCharsToRemove)>0:
        procText = re.sub(specialCharsToRemove,' ',procText)

    # Normalize to lower case
    if convertToLower:
        procText = procText.lower() 

    # Replace multiple consecutive spaces with just one space
    if removeConsecutiveSpaces:
        procText = re.sub(' +', ' ', procText)

    return procText

# %%
# Tokenize words
def tokenize_words(words):
    if (type(words) != str) or (word_tokenize(words) == ''):
        return np.nan
    else:
        return word_tokenize(words)

# %% [markdown]
# ### Analysis

# %%
# Create a dataframe with only the description
processedReviews =  pd.DataFrame(data=ds.RevDescription.apply(textPreProcess).values, index=ds.index, columns=['PreProcessedText'])
# Out:
# /Users/nunoantonio/opt/anaconda3/lib/python3.8/site-packages/bs4/__init__.py:435: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   warnings.warn(

# %%
# Tokenize text
processedReviews['Words'] =  processedReviews['PreProcessedText'].apply(tokenize_words)

# %% [markdown]
# #### English

# %%
Tags=processedReviews.Words.apply(nltk.pos_tag)

# %%
print(Tags[0])
# Out:
# [('the', 'DT'), ('russian', 'JJ'), ('ministry', 'NN'), ('of', 'IN'), ('defense', 'NN'), ('mod', 'NN'), ('has', 'VBZ'), ('released', 'VBN'), ('a', 'DT'), ('video', 'NN'), ('showing', 'VBG'), ('the', 'DT'), ('work', 'NN'), ('of', 'IN'), ('army', 'NN'), ('sappers', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('zone', 'NN'), ('of', 'IN'), ('moscow', 'NN'), ('s', 'NN'), ('special', 'JJ'), ('military', 'JJ'), ('operation', 'NN'), ('in', 'IN'), ('ukraine', 'NN'), ('in', 'IN'), ('footage', 'NN'), ('published', 'VBN'), ('on', 'IN'), ('the', 'DT'), ('mod', 'NN'), ('s', 'NN'), ('telegram', 'NN'), ('page', 'NN'), ('the', 'DT'), ('servicemen', 'NNS'), ('are', 'VBP'), ('seen', 'VBN'), ('performing', 'VBG'), ('a', 'DT'), ('controlled', 'JJ'), ('explosion', 'NN'), ('of', 'IN'), ('the', 'DT'), ('projectiles', 'NNS'), ('that', 'WDT'), ('had', 'VBD'), ('apparently', 'RB'), ('been', 'VBN'), ('abandoned', 'VBN'), ('by', 'IN'), ('ukrainian', 'JJ'), ('units', 'NNS'), ('and', 'CC'), ('then', 'RB'), ('detected', 'VBN'), ('by', 'IN'), ('russian', 'JJ'), ('forces', 'NNS'), ('in', 'IN'), ('an', 'DT'), ('unspecified', 'JJ'), ('area', 'NN'), ('the', 'DT'), ('mod', 'NN'), ('quoted', 'VBD'), ('a', 'DT'), ('demining', 'VBG'), ('platoon', 'NN'), ('commander', 'NN'), ('as', 'IN'), ('saying', 'VBG'), ('that', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('shells', 'NNS'), ('have', 'VBP'), ('already', 'RB'), ('been', 'VBN'), ('destroyed', 'VBN'), ('sowing', 'VBG'), ('machinery', 'NN'), ('will', 'MD'), ('soon', 'RB'), ('ride', 'VB'), ('across', 'IN'), ('these', 'DT'), ('fields', 'NNS'), ('and', 'CC'), ('life', 'NN'), ('will', 'MD'), ('return', 'VB'), ('back', 'RB'), ('to', 'TO'), ('normal', 'JJ'), ('there', 'EX'), ('he', 'PRP'), ('added', 'VBD')]

# %%
# Filter only Nouns
nouns = []
for tags in Tags:
    for tag in tags:
        if tag[1][0]=="N":  # if if starts with a "N"
            nouns.append(tag[0])
print(nouns)
# Out:
# ['ministry', 'defense', 'mod', 'video', 'work', 'army', 'sappers', 'zone', 'moscow', 's', 'operation', 'ukraine', 'footage', 'mod', 's', 'telegram', 'page', 'servicemen', 'explosion', 'projectiles', 'units', 'forces', 'area', 'mod', 'platoon', 'commander', 'shells', 'machinery', 'fields', 'life', 'day', 'aviation', 'combat', 'sorties', 'area', 'group', 'artillery', 'fire', 'tasks', 'soldiers', 'tank', 'vehicles', 'cars', 'howitzer', 'direction', 'defense', 'ministry', 'defense', 'department', 'ammunition', 'depot', 'armed', 'forces', 'village', 'novoukrainka', 'donetsk', 'people', 'result', 'strike', 'echelon', 'railway', 'station', 'town', 'kramatorsk', 'donetsk', 'people', 'tonnes', 's', 'forces', 'ammunition', 'ministry', 'countries', 'kiev', 'types', 'weapon', 'systems', 'air', 'defense', 'missiles', 'rocket', 'systems', 'tanks', 'artillery', 'anti', 'aircraft', 'guns', 'russia', 'operation', 'ukraine', 'year', 'kremlin', 'arms', 'deliveries', 'ukraine', 'russia', 'spring', 'year', 'number', 'officials', 'willingness', 'forces', 'ukraine', 'efforts', 'warehouses', 'soviet\xad', 'weapons', 'salt', 'mines', 'soledar', 'town', 'russian', 'soldier', 'sputnik', 'depots', 'village', 'paraskoviyevka', 'troops', 'explosives', 'warehouses', 'facilities', 'bombs', 'explosions', 'warehouses', 'mistake', 'bombs', 'blast', 'surface', 'depots', 'tons', 'tnt', 'sappers', 'salt', 'soldier', 'lot', 'arms', 'ammunition', 'place', 'depots', 'boxes', 'ppshs', 'gun', 'world', 'war', 'box', 'arm', 'pieces', 'volumes', 'weaponry', 'types', 'arms', 'warehouses', 'russia', 'ministry', 'defense', 'mod', 'liberation', 'soledar', 'towns', 'seversk', 'artemovsk', 'part', 'moscow', 's', 'operation', 'mod', 'time', 'capture', 'settlement', 'supply', 'routes', 'forces', 'artemovsk', 'bakhmut', 'post', 'coup', 'government', 'liberation', 'settlement', 'soledar', 'continuation', 'operations', 'region', 'evening', 'mod', 'spokesman', 'igor', 'konashenkov', 'briefing', 'time', 'liberation', 'soledar', 'forces', 'troops', 'area', 'cauldron', 'developments', 'fighting', 'parts', 'artemovsk', 'forces', 'quarters', 'units', 'troops', 'enemy', 'outskirts', 'town', 'strikes', 'army', 'aviation', 'rocket', 'artillery', 'units', 'defeat', 'forces', 'settlements', 'bogdanovka', 'artemovskoye', 'hours', 'servicepeople', 'mercenaries', 'fighting', 'vehicles', 'vehicles', 'd', 'howitzer', 'self', 'unit', 'gvozdika', 'direction', 'ministry', 'defense', 'ministry', 'russian', 'forces', 'soldiers', 'missile', 'strike', 'settlement', 'forces', 'donetsk', 'people', 'result', 'missile', 'strike', 'deployment', 'points', 'th', 'brigade', 'armed', 'forces', 'units', 'operation', 'forces', 'settlement', 'konstantinovka', 'donetsk', 'people', 'soldiers', 'injuries', 'degrees', 'severity', 'department', 'ministry', 'kiev', 'servicepeople', 'kupyansk', 'krasny', 'directions', 'day', 'soldiers', 'forces', 'kherson', 'direction', 'defense', 'ministry', 'sputnik', 'video', 'grad', 'multiple', 'launch', 'rocket', 'system', 'artillery', 'km', 'line', 'part', 'moscow', 's', 'operation', 'footage', 'explosions', 'distance', 'sign', 'mlrs', 'hardware', 'serviceman', 'sputnik', 'army', 's', 'offensive', 'area', 'kiev', 'artillery', 'line', 'contact', 'video', 'grad', 'system', 'gunpowder', 'plenty', 'smoke', 'result', 'rocket', 'strike', 'serviceman', 'artillery', 'units', 'damage', 'command', 'observation', 'post', 'control', 'post', 'vehicles', 'th', 'brigade', 'defense', 'forces', 'forces', 'ukraine', 'warehouse', 'ammunition', 'equipment', 'city', 'kherson', 'spokesperson', 'spokesperson', 'enemy', 'losses', 'people', 'enemy', 'combat', 'vehicles', 'announcement', 'hours', 'reports', 'strikes', 'civilians', 'russia', 'bryansk', 'region', 'damages', 'bryansk', 'governor', 'alexander', 'bogomaz', 'strikes', 'village', 'district', 'midnight', 'start', 'operation', 'regions', 'russia', 'border', 'fire', 'forces', 'forces', 'cruise', 'missile', 'strike', 'kherson', 'command', 'defense', 'min ...

# %%
nlp = spacy.load(
    "en_core_web_sm"
)  # Load language model (python -m spacy download es_core_news_sm). More models in https://spacy.io/models
Spacetags= processedReviews.PreProcessedText.apply(nlp)
for token in Spacetags[0]:
    print(token, token.pos_)
# Out:
# the DET
# russian ADJ
# ministry PROPN
# of ADP
# defense PROPN
# mod PROPN
# has AUX
# released VERB
# a DET
# video NOUN
# showing VERB
# the DET
# work NOUN
# of ADP
# army NOUN
# sappers NOUN
# in ADP
# the DET
# zone NOUN
# of ADP
# moscow PROPN
# s PART
# special ADJ
# military ADJ
# operation NOUN
# in ADP
# ukraine PROPN
# in ADP
# footage NOUN
# published VERB
# on ADP
# the DET
# mod PROPN
# s PROPN
# telegram PROPN
# page NOUN
# the DET
# servicemen NOUN
# are AUX
# seen VERB
# performing VERB
# a DET
# controlled VERB
# explosion NOUN
# of ADP
# the DET
# projectiles NOUN
# that PRON
# had AUX
# apparently ADV
# been AUX
# abandoned VERB
# by ADP
# ukrainian ADJ
# units NOUN
# and CCONJ
# then ADV
# detected VERB
# by ADP
# russian ADJ
# forces NOUN
# in ADP
# an DET
# unspecified ADJ
# area NOUN
# the DET
# mod PROPN
# quoted VERB
# a DET
# demining VERB
# platoon NOUN
# commander NOUN
# as ADP
# saying VERB
# that SCONJ
# more ADJ
# than ADP
# shells NOUN
# have AUX
# already ADV
# been AUX
# destroyed VERB
# sowing VERB
# machinery NOUN
# will AUX
# soon ADV
# ride VERB
# across ADP
# these DET
# fields NOUN
# and CCONJ
# life NOUN
# will AUX
# return VERB
# back ADV
# to ADP
# normal ADJ
# there ADV
# he PRON
# added VERB

# %%
# Filter only Adjectives
adjectives = []
for result in Spacetags:
    for token in result:
        if token.pos_=="ADJ":
            adjectives.append(token)
print(adjectives)
# Out:
# [russian, special, military, ukrainian, russian, unspecified, more, normal, past, ukrainian, armored, ukrainian, armed, donetsk, donetsk, ukrainian, armed, western, various, multiple, anti, military, further, western, armed, underground, unnamed, russian, nearby, ukrainian, incendiary, incendiary, intact, small, common, soviet, second, such, small, other, small, complete, special, military, strategic, possible, ukrainian, important, successful, offensive, donetsk, russian, ukrainian, nearby, latest, heavy, underway, western, russian, russian, airborne, northern, southern, ukrainian, past, ukrainian, foreign, armored, russian, armed, ukrainian, temporary, ukraine, donetsk, temporary, mechanized, ukrainian, armed, ukraine, special, ukrainian, past, ukrainian, russian, russian, grad, russian, multiple, ukrainian, front, special, military, several, russian, ukrainian, military, russian, russian, grad, russian, unmanned, aerial, territorial, armed, ukrainian, structural, bryansk, special, military, ukrainian, russian, russian, russian, armed, long, afu, military, different, counteroffensive, international, new, territorial, least, past, ukrainian, military, modern, main, russian, defensive, pre, soviet, ukrainian, armed, heavy, civilian, diversionary, russian, military, wild, western, mainstream, ukrainian, concrete, much, significant, collective, own, huge, international, russian, long, aware, more, fascinating, political, total, more, ukrainian, armored, akatsiya, past, russian, donetsk, special, military, donetsk, lugansk, ukrainian, western, comprehensive, ukraine, special, good, particular, urban, heavy, ukrainian, last, foreign, ukrainian, open, square, square, social, preliminary, russian, surface, western, military, ukrainian, ukrainian, first, ukrainian, massive, high, only, capable, engaging, preliminary, square, square, later, civilian, preliminary, different, unmanned, aerial, local, intact, aerial, russian, ukrainian, russian, aerial, uav, aerial, russian, ukrainian, special, russian, ukrainian, upper, russian, thermobaric, ukrainian, dpr, russian, ukrainian, ukrainian, russian, ukrainian, nuclear, atomic, nuclear, able, dirty, nuclear, nuclear, russian, nuclear, false, nuclear, nuclear, nuclear, scientific, actionable, public, congressional, national, radiological, nuclear, military, present, regular, seventh, next, left, dnepr, largest, nuclear, early, international, possible, nuclear, international, rotational, multiple, russian, russian, specific, least, ukrainian, public, preliminary, public, deceased, ukrainian, public, more, ukrainian, armored, western, more, north, western, western, south, western, special, military, lugansk, available, armed, first, republican, special, military, russian, deputy, able, free, toxic, du, challenger, main, official, armed, potent, anti, further, grim, evident, anti, russian, military, radioactive, grave, local, low, environmental, parliamentary, scottish, operational, clear, official, military, eager, aware, armed, depleted, russian, du, radioactive, relevant, such, former, aware, such, effective, modern, armored, multiple, grim, nuclear, dirty, perilous, such, potential, collective, military, russian, western, mass, true, different, dangerous, former, ukrainian, current, nuclear, whole, nuclear, safe, nuclear, russian, nuclear, nuclear, radioactive, russian, nuclear, international, atomic, ukrainian, close, explosive, left, dnepr, largest, nuclear, nuclear, ukrainian, russian, investigative, french, russian, investigative, investigative, french, ukrainian, armed, russian, blank, terrorist, parliamentary, ukrainian, armed, operational, clear, high, such, significant, radioactive, unprocessed, tiny, radioactive, high, such, massive, true, technical, anti, other, capable, quick, swift, armored, american, civil, military, russian, armored, great, instrumental, upa, nazi, late, last, private, military, constitutional, special, military, more, proud, special, military, many, armed, ma ...

# %%
df = pd.Series(adjectives)
df = df.astype(str)

# %%
bow = df.value_counts(0)

# %%
df.head()
# Out:
# 0      russian
# 1      special
# 2     military
# 3    ukrainian
# 4      russian
# dtype: object

# %%
bow.head(30)
# Out:
# russian          4801
# ukrainian        3877
# military         3053
# special          1457
# western          1090
# other             835
# nuclear           758
# lugansk           612
# more              605
# new               574
# armed             554
# ukraine           549
# foreign           518
# last              505
# donetsk           497
# such              469
# international     401
# dpr               388
# former            377
# anti              372
# same              341
# many              337
# latest            336
# several           328
# european          317
# civilian          304
# possible          301
# high              288
# humanitarian      281
# first             275
# Name: count, dtype: int64

# %%
from collections import defaultdict

my_dict = defaultdict(int)
print(my_dict['nonexistent_key'])  # Accessing a non-existent key

# Output: 0
# Out:
# 0

# %%
    # Create a defaultdict to store word frequencies
    word_frequency = defaultdict(int)
    
    # Count the frequency of each word
    for word in adjectives
        word_frequency[word] += 1
    
    return word_frequency

# Example usage
frequency = count_word_frequency(adjectives)
print(frequency)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/v4/8yk6c62s7nv77xj532727jcr0000gn/T/ipykernel_16877/3619055893.py in <module>
#       3
#       4 # Count the frequency of each word
# ----> 5 for word in words:
#       6     word_frequency[word] += 1
#       7
#
# NameError: name 'words' is not defined
